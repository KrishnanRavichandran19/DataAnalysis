# %%
import	pandas as pd
import numpy as np
import csv

data = pd.read_csv('Pressure_20220106.csv', sep=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#                                 Datum Zeit  ... Pres. Float 8 (Adam6017A3AIn2)
# 0  Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                          0.183
# 1  Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                          0.183
# 2  Thu Jan 06 2022 00:00:03 GMT+0100 (CET)  ...                          0.183
# 3  Thu Jan 06 2022 00:00:04 GMT+0100 (CET)  ...                          0.183
# 4  Thu Jan 06 2022 00:00:05 GMT+0100 (CET)  ...                          0.183
#
# [5 rows x 11 columns]

# %%
data.tail()
# Out:
#                                     Datum Zeit  ... Pres. Float 8 (Adam6017A3AIn2)
# 69415  Thu Jan 06 2022 23:59:54 GMT+0100 (CET)  ...                          0.184
# 69416  Thu Jan 06 2022 23:59:55 GMT+0100 (CET)  ...                          0.184
# 69417  Thu Jan 06 2022 23:59:56 GMT+0100 (CET)  ...                          0.184
# 69418  Thu Jan 06 2022 23:59:57 GMT+0100 (CET)  ...                          0.184
# 69419  Thu Jan 06 2022 23:59:59 GMT+0100 (CET)  ...                          0.184
#
# [5 rows x 11 columns]

# %%
data.describe()
# Out:
#        Pres. Comp. (Adam6017A8AIn4)  ...  Pres. Float 8 (Adam6017A3AIn2)
# count                  6.942000e+04  ...                    6.942000e+04
# mean                   9.147221e+04  ...                    1.440691e+03
# std                    9.520334e+05  ...                    1.200133e+05
# min                    0.000000e+00  ...                    1.700000e-01
# 25%                    3.000000e-03  ...                    1.800000e-01
# 50%                    4.000000e-03  ...                    1.840000e-01
# 75%                    5.000000e-03  ...                    1.870000e-01
# max                    9.999999e+06  ...                    9.999999e+06
#
# [8 rows x 9 columns]

# %%
 data.corr()
# Out:
#                                 Pres. Comp. (Adam6017A8AIn4)  ...  Pres. Float 8 (Adam6017A3AIn2)
# Pres. Comp. (Adam6017A8AIn4)                        1.000000  ...                        0.124925
# Pres. Float 1 (Adam6017A7AIn1)                      0.124925  ...                        1.000000
# Pres. Float 2 (Adam6017A7AIn2)                      0.124925  ...                        1.000000
# Pres. Float 3 (Adam6017A7AIn3)                      0.124925  ...                        1.000000
# Pres. Float 4 (Adam6217A5AIn0)                      0.124925  ...                        1.000000
# Pres. Float 5 (Adam6217A5AIn1)                      0.124925  ...                        1.000000
# Pres. Float 6 (Adam6017A3AIn0)                      0.124925  ...                        1.000000
# Pres. Float 7 (Adam6017A3AIn1)                      0.124925  ...                        1.000000
# Pres. Float 8 (Adam6017A3AIn2)                      0.124925  ...                        1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69420 entries, 0 to 69419
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Datum Zeit                      69420 non-null  object
#  1   Timestamp                       69420 non-null  object
#  2   Pres. Comp. (Adam6017A8AIn4)    69420 non-null  float64
#  3   Pres. Float 1 (Adam6017A7AIn1)  69420 non-null  float64
#  4   Pres. Float 2 (Adam6017A7AIn2)  69420 non-null  float64
#  5   Pres. Float 3 (Adam6017A7AIn3)  69420 non-null  float64
#  6   Pres. Float 4 (Adam6217A5AIn0)  69420 non-null  float64
#  7   Pres. Float 5 (Adam6217A5AIn1)  69420 non-null  float64
#  8   Pres. Float 6 (Adam6017A3AIn0)  69420 non-null  float64
#  9   Pres. Float 7 (Adam6017A3AIn1)  69420 non-null  float64
#  10  Pres. Float 8 (Adam6017A3AIn2)  69420 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 5.8+ MB

# %%
import datetime

timestamp = "1523126888080"
your_dt = datetime.datetime.fromtimestamp(int(timestamp)/1000)  # using the local timezone
print(your_dt.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2018-04-07 18:48:08

# %%
import datetime

timestamp = "1640127598927"
your_dt = datetime.datetime.fromtimestamp(int(timestamp)/1000)  # using the local timezone
print(your_dt.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2021-12-21 22:59:58

# %%
import datetime

timestamp = "1640127600043"
your_dt = datetime.datetime.fromtimestamp(int(timestamp)/1000)  # using the local timezone
print(your_dt.strftime("%Y-%m-%d %H:%M:%S"))


1640213998038
# Out:
# 2021-12-21 23:00:00
# 1640213998038

# %%
import datetime

timestamp = "1640213998038"
your_dt = datetime.datetime.fromtimestamp(int(timestamp)/1000)  # using the local timezone
print(your_dt.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2021-12-22 22:59:58

# %%
data.shape
# Out:
# (69582, 11)

# %%
data.mean()
# Out:
# 0.006      15233.850879
# 0.185       1437.339421
# 0.186       1437.334660
# 0.192       1437.347518
# 0.192.1     1437.342205
# 0.179       1437.328411
# 0.178       1437.328848
# 0.198       1437.351410
# 0.180       1437.338281
# dtype: float64

# %%
data['Timestamp'].value_counts()
# Out:
# undefined        6
# 1640209255636    1
# 1640145520314    1
# 1640153553834    1
# 1640213660510    1
#                 ..
# 1640157149741    1
# 1640150797877    1
# 1640131541902    1
# 1640203245192    1
# 1640187406569    1
# Name: Timestamp, Length: 72088, dtype: int64

# %%
data.Timestamp = pd.to_numeric(data.Timestamp, errors='coerce')

# %%
data.head()
# Out:
#                                 Datum Zeit  ...  Pres. Float 8 (Adam6017A3AIn2)
# 0  Wed Dec 22 2021 00:00:00 GMT+0100 (CET)  ...                           0.174
# 1  Wed Dec 22 2021 00:00:01 GMT+0100 (CET)  ...                           0.174
# 2  Wed Dec 22 2021 00:00:02 GMT+0100 (CET)  ...                           0.174
# 3  Wed Dec 22 2021 00:00:04 GMT+0100 (CET)  ...                           0.174
# 4  Wed Dec 22 2021 00:00:05 GMT+0100 (CET)  ...                           0.174
#
# [5 rows x 11 columns]

# %%
data_1 = data['Timestamp']

# %%
data

# %%
data_1
# Out:
# 0        1641423598748
# 1        1641423600038
# 2        1641423601901
# 3        1641423603071
# 4        1641423604325
#              ...
# 69415    1641509992862
# 69416    1641509994186
# 69417    1641509995509
# 69418    1641509996595
# 69419    1641509997836
# Name: Timestamp, Length: 69420, dtype: object

# %%
data_2 = data_1.head()
data_2.columns = ['Timestamp']
data_2.head(2)
type(data_2)
# Out:
# pandas.core.series.Series

# %%
import datetime
for i in data_2: 
  timestamp = i
  your_dt = datetime.datetime.fromtimestamp(int(timestamp)/1000)  # using the local timezone
  data_3 = (your_dt.strftime("%Y-%m-%d %H:%M:%S"))
  data_3

# %%
data_3
# Out:
# '2022-01-05 23:00:04'

# %%
data_x = data
data_x

# %%
data_1
# Out:
# 0        1641423598748
# 1        1641423600038
# 2        1641423601901
# 3        1641423603071
# 4        1641423604325
#              ...
# 69415    1641509992862
# 69416    1641509994186
# 69417    1641509995509
# 69418    1641509996595
# 69419    1641509997836
# Name: Timestamp, Length: 69420, dtype: object

# %%
type(data_x['Timestamp'])
# Out:
# pandas.core.series.Series

# %%
data["Timestamp"] = data["Timestamp"].astype(str).astype(int)
  
print(data.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-9b7ae7ac2610> in <module>()
# ----> 1 data["Timestamp"] = data["Timestamp"].astype(str).astype(int)
#       2
#       3 print(data.dtypes)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# ...

# %%
# Iterate over two given columns only from the dataframe
for column in data[['Timestamp']]:
   # Select column contents by column name using [] operator
   columnSeriesObj = data[column]
   print('Colunm Name : ', column)
   print('Column Contents : ', columnSeriesObj.values)
# Out:
# Colunm Name :  Timestamp
# Column Contents :  ['1641423598748' '1641423600038' '1641423601901' ... '1641509995509'
#  '1641509996595' '1641509997836']

# %%
data.Timestamp = data.Timestamp.round(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-a4aec69582fc> in <module>()
# ----> 1 data.Timestamp = data.Timestamp.round(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in round(self, decimals, *args, **kwargs)
#    2217         """
#    2218         nv.validate_round(args, kwargs)
# -> 2219         result = self._values.round(decimals)
#    2220         result = self._constructor(result, index=self.index).__finalize__(
#    2221             self, method="round"
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
data["Timestamp"] = pd.to_numeric(data["Timestamp"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "undefined"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-37d62f4eee52> in <module>()
# ----> 1 data["Timestamp"] = pd.to_numeric(data["Timestamp"])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     151         try:
#     152             values = lib.maybe_convert_numeric(
# --> 153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#     155         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
data_x['Timestamp'] = data_x['Timestamp'].apply(lambda x: x / 10 ** (len((str(x))) - 2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-ae933f3ecde8> in <module>()
# ----> 1 data_x['Timestamp'] = data_x['Timestamp'].apply(lambda x: x / 10 ** (len((str(x))) - 2))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-41-ae933f3ecde8> in <lambda>(x)
# ----> 1 data_x['Timestamp'] = data_x['Timestamp'].apply(lambda x: x / 10 ** (len((str(x))) - 2))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
type(data_3)
# Out:
# str

# %%
pd.to_datetime(data_2.Timestamp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-c009ced2b928> in <module>()
# ----> 1 pd.to_datetime(data_2.Timestamp)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'Timestamp'

# %%
## Here we will check the percentage of nan values present in each feature
## 1 -step make the list of features which has missing values
features_with_na=[features for features in data.columns if data[features].isnull().sum()>1]
## 2- step print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, np.round(data[feature].isnull().mean(), 4),  ' % missing values')

# %%
data
# Out:
#                                     Datum Zeit  ... Pres. Float 8 (Adam6017A3AIn2)
# 0      Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                          0.183
# 1      Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                          0.183
# 2      Thu Jan 06 2022 00:00:03 GMT+0100 (CET)  ...                          0.183
# 3      Thu Jan 06 2022 00:00:04 GMT+0100 (CET)  ...                          0.183
# 4      Thu Jan 06 2022 00:00:05 GMT+0100 (CET)  ...                          0.183
# ...                                        ...  ...                            ...
# 69415  Thu Jan 06 2022 23:59:54 GMT+0100 (CET)  ...                          0.184
# 69416  Thu Jan 06 2022 23:59:55 GMT+0100 (CET)  ...                          0.184
# 69417  Thu Jan 06 2022 23:59:56 GMT+0100 (CET)  ...                          0.184
# 69418  Thu Jan 06 2022 23:59:57 GMT+0100 (CET)  ...                          0.184
# ...

# %%
df=data

# %%
df

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Timestamp'],data['Pres. Comp. (Adam6017A8AIn4)'])
plt.xlabel('Time')
plt.ylabel('SalePrice')
plt.show()

# %%
import seaborn as sns
sns.jointplot(x=data['Timestamp'],y=data['Pres. Comp. (Adam6017A8AIn4)'],color='Red');

# %%
data['Pres. Comp. (Adam6017A8AIn4)'].plot()

# %%
data.head()
# Out:
#                                 Datum Zeit  ... Pres. Float 8 (Adam6017A3AIn2)
# 0  Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                          0.183
# 1  Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                          0.183
# 2  Thu Jan 06 2022 00:00:03 GMT+0100 (CET)  ...                          0.183
# 3  Thu Jan 06 2022 00:00:04 GMT+0100 (CET)  ...                          0.183
# 4  Thu Jan 06 2022 00:00:05 GMT+0100 (CET)  ...                          0.183
#
# [5 rows x 11 columns]

# %%
data['Pres. Float 1 (Adam6017A7AIn1)'].plot()

# %%
data_PC1 = data.loc[(data['Pres. Comp. (Adam6017A8AIn4)'] <= 1000)]

# %%
data_PC1
# Out:
#                                     Datum Zeit  ... Pres. Float 8 (Adam6017A3AIn2)
# 0      Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                          0.183
# 1      Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                          0.183
# 2      Thu Jan 06 2022 00:00:03 GMT+0100 (CET)  ...                          0.183
# 3      Thu Jan 06 2022 00:00:04 GMT+0100 (CET)  ...                          0.183
# 4      Thu Jan 06 2022 00:00:05 GMT+0100 (CET)  ...                          0.183
# ...                                        ...  ...                            ...
# 69415  Thu Jan 06 2022 23:59:54 GMT+0100 (CET)  ...                          0.184
# 69416  Thu Jan 06 2022 23:59:55 GMT+0100 (CET)  ...                          0.184
# 69417  Thu Jan 06 2022 23:59:56 GMT+0100 (CET)  ...                          0.184
# 69418  Thu Jan 06 2022 23:59:57 GMT+0100 (CET)  ...                          0.184
# ...

# %%
data_PC1['Pres. Comp. (Adam6017A8AIn4)'].plot()
data_PC1['Pres. Float 1 (Adam6017A7AIn1)'].plot()
data_PC1['Pres. Float 2 (Adam6017A7AIn2)'].plot()
data_PC1['Pres. Float 3 (Adam6017A7AIn3)'].plot()
data_PC1['Pres. Float 4 (Adam6217A5AIn0)'].plot()
data_PC1['Pres. Float 5 (Adam6217A5AIn1)'].plot()
data_PC1['Pres. Float 6 (Adam6017A3AIn0)'].plot()
data_PC1['Pres. Float 7 (Adam6017A3AIn1)'].plot()
data_PC1['Pres. Float 8 (Adam6017A3AIn2)'].plot()

# %%
import matplotlib.pyplot as plt

plt.scatter(data_PC1['Datum Zeit'],data_PC1['Pres. Comp. (Adam6017A8AIn4)'])
plt.xlabel('Time')
plt.ylabel('PC')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c2edb59b1cee> in <module>()
#       4 plt.xlabel('Time')
#       5 plt.ylabel('PC')
# ----> 6 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# ...

# %%
Temp_data = pd.read_csv('Temperature_20220106.csv', sep=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Temp_data
Temp_data_1 = Temp_data

# %%
data_PC1_1 = data_PC1.head(100)

# %%
Temp_data.columns
# Out:
# Index(['Datum Zeit', 'Timestamp', 'Air Temp. Met (Adam6017A8AIn0)',
#        'Air Temp. PV (Adam6015A4RTDIn2)', 'Memb. Temp 1 (Adam6217A6AIn2)',
#        'Memb. Temp 2 (Adam6217A6AIn3)', 'Panel Temp. 1 (Adam6015A4RTDIn0)',
#        'Panel Temp. 2 (Adam6015A4RTDIn1)', 'Panel Temp. 3 (Adam6217A6AIn0)',
#        'Panel Temp. 4 (Adam6217A6AIn1)', 'Irrad. Temp. 1 (Adam6015A4RTDIn3)',
#        'Irrad. Temp. 2 (Adam6015A4RTDIn4)',
#        'Irrad. Temp. 3 (Adam6015A4RTDIn5)',
#        'Irrad. Temp. 4 (Adam6015A4RTDIn6)', 'Water temp. (Adam6017A7AIn0)',
#        'Blower Temp. (Adam6017A8AIn7)'],
#       dtype='object')

# %%
Temp_data = Temp_data.loc[(Temp_data['Air Temp. Met (Adam6017A8AIn0)'] <= 1000)]

# %%
Temp_data['Air Temp. Met (Adam6017A8AIn0)'].plot()
Temp_data['Air Temp. PV (Adam6015A4RTDIn2)'].plot()
Temp_data['Memb. Temp 1 (Adam6217A6AIn2)'].plot()

Temp_data['Panel Temp. 1 (Adam6015A4RTDIn0)'].plot()
Temp_data['Panel Temp. 2 (Adam6015A4RTDIn1)'].plot()
Temp_data['Panel Temp. 3 (Adam6217A6AIn0)'].plot()
Temp_data['Panel Temp. 4 (Adam6217A6AIn1)'].plot()
Temp_data['Irrad. Temp. 1 (Adam6015A4RTDIn3)'].plot()
Temp_data['Irrad. Temp. 2 (Adam6015A4RTDIn4)'].plot()
Temp_data['Irrad. Temp. 3 (Adam6015A4RTDIn5)'].plot()
Temp_data['Irrad. Temp. 4 (Adam6015A4RTDIn6)'].plot()
Temp_data['Water temp. (Adam6017A7AIn0)'].plot()

# %%
Wind_data = pd.read_csv('Wind dir. + Irrad + DO_20220106.csv', sep=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Wind_data.head()
# Out:
#                                 Datum Zeit  ... Thermal Switch (Adam6717GDIn3)
# 0  Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                           true
# 1  Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                           true
# 2  Thu Jan 06 2022 00:00:03 GMT+0100 (CET)  ...                           true
# 3  Thu Jan 06 2022 00:00:04 GMT+0100 (CET)  ...                           true
# 4  Thu Jan 06 2022 00:00:05 GMT+0100 (CET)  ...                           true
#
# [5 rows x 10 columns]

# %%
Wind_data.columns
# Out:
# Index(['Datum Zeit', 'Timestamp', 'Wind Direction (Adam6017A8AIn5)',
#        'Irradiation 1 (Adam6217A5AIn2)', 'Irradiation 2 (Adam6217A5AIn3',
#        'Irradiation 3 (Adam6217A5AIn4)', 'Irradiation 4 (Adam6217A5AIn5)',
#        'Alarm reset (Adam6717GDIn1)', 'Blower switch alarm (Adam6717GDIn2)',
#        'Thermal Switch (Adam6717GDIn3)'],
#       dtype='object')

# %%
Wind_data = Wind_data.loc[(Wind_data['Wind Direction (Adam6017A8AIn5)'] <= 1000)]

# %%
Wind_data['Wind Direction (Adam6017A8AIn5)'].plot()
Wind_data['Irradiation 1 (Adam6217A5AIn2)'].plot()
Wind_data['Irradiation 2 (Adam6217A5AIn3'].plot()
Wind_data['Irradiation 3 (Adam6217A5AIn4)'].plot()
Wind_data['Irradiation 4 (Adam6217A5AIn5)'].plot()

# %%
Wave_data = pd.read_csv('Wave Ht. + WS + Force_20220106.csv', sep=",")

# %%
Wave_data.columns
# Out:
# Index(['Datum Zeit', 'Timestamp', 'Wave Height (Adam6217A6AIn7)',
#        'Wind Speed - Met (Adam6017A8AIn6)',
#        'Wind Speed - float 1 (Adam6217A5AIn6)',
#        'Wind Speed - float 2 (Adam6217A5AIn7)',
#        'Force - float 1 (Adam6017A3AIn3)', 'Force - float 2 (Adam6017A3AIn4)',
#        'Force - float 3 (Adam6017A3AIn5)', 'Force - float 4 (Adam6217A6AIn4)'],
#       dtype='object')

# %%
Wave_data = Wave_data.loc[(Wave_data['Wind Speed - Met (Adam6017A8AIn6)'] <= 1000)]
Wave_data = Wave_data.loc[(Wave_data['Wind Speed - float 1 (Adam6217A5AIn6)'] <= 1000)]
Wave_data = Wave_data.loc[(Wave_data['Wind Speed - float 2 (Adam6217A5AIn7)'] <= 1000)]
Wave_data = Wave_data.loc[(Wave_data['Force - float 1 (Adam6017A3AIn3)'] <= 1000)]
Wave_data = Wave_data.loc[(Wave_data['Force - float 2 (Adam6017A3AIn4)'] <= 1000)]
Wave_data = Wave_data.loc[(Wave_data['Force - float 3 (Adam6017A3AIn5)'] <= 1000)]
Wave_data = Wave_data.loc[(Wave_data['Force - float 4 (Adam6217A6AIn4)'] <= 1000)]

# %%
Wave_data['Wind Speed - Met (Adam6017A8AIn6)'].plot()
Wave_data['Wind Speed - float 1 (Adam6217A5AIn6)'].plot()
Wave_data['Wind Speed - float 2 (Adam6217A5AIn7)'].plot()
Wave_data['Force - float 1 (Adam6017A3AIn3)'].plot()
Wave_data['Force - float 2 (Adam6017A3AIn4)'].plot()
Wave_data['Force - float 3 (Adam6017A3AIn5)'].plot()
Wave_data['Force - float 4 (Adam6217A6AIn4)'].plot()

# %%
Wave_data
# Out:
#                                      Datum Zeit  ...  Force - float 4 (Adam6217A6AIn4)
# 0       Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                              1.91
# 1       Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                              1.91
# 2       Thu Jan 06 2022 00:00:02 GMT+0100 (CET)  ...                              1.91
# 3       Thu Jan 06 2022 00:00:02 GMT+0100 (CET)  ...                              1.91
# 4       Thu Jan 06 2022 00:00:02 GMT+0100 (CET)  ...                              1.91
# ...                                         ...  ...                               ...
# 245799  Thu Jan 06 2022 23:59:58 GMT+0100 (CET)  ...                              2.00
# 245800  Thu Jan 06 2022 23:59:59 GMT+0100 (CET)  ...                              2.00
# 245801  Thu Jan 06 2022 23:59:59 GMT+0100 (CET)  ...                              2.00
# 245802  Thu Jan 06 2022 23:59:59 GMT+0100 (CET)  ...                              2.00
# ...

# %%
data
# Out:
#                                     Datum Zeit  ... Pres. Float 8 (Adam6017A3AIn2)
# 0      Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                          0.183
# 1      Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                          0.183
# 2      Thu Jan 06 2022 00:00:03 GMT+0100 (CET)  ...                          0.183
# 3      Thu Jan 06 2022 00:00:04 GMT+0100 (CET)  ...                          0.183
# 4      Thu Jan 06 2022 00:00:05 GMT+0100 (CET)  ...                          0.183
# ...                                        ...  ...                            ...
# 69415  Thu Jan 06 2022 23:59:54 GMT+0100 (CET)  ...                          0.184
# 69416  Thu Jan 06 2022 23:59:55 GMT+0100 (CET)  ...                          0.184
# 69417  Thu Jan 06 2022 23:59:56 GMT+0100 (CET)  ...                          0.184
# 69418  Thu Jan 06 2022 23:59:57 GMT+0100 (CET)  ...                          0.184
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data_PC1_1['Timestamp'],data_PC1_1['Pres. Comp. (Adam6017A8AIn4)'])
plt.xlabel('Time')
plt.ylabel('PC')
plt.show()

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'],unit='s')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.cast_from_unit()
#
# OverflowError: Python int too large to convert to C long
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-106-1bbe84fe5b28> in <module>()
# ----> 1 data['Timestamp'] = pd.to_datetime(data['Timestamp'],unit='s')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     801             result = arg.map(cache_array)
#     802         else:
# --> 803             values = convert_listlike(arg._values, format)
# ...

# %%
data['Timestamp'].isnull
# Out:
# <bound method Series.isnull of 0        1641423598748
# 1        1641423600038
# 2        1641423601901
# 3        1641423603071
# 4        1641423604325
#              ...
# 69415    1641509992862
# 69416    1641509994186
# 69417    1641509995509
# 69418    1641509996595
# 69419    1641509997836
# Name: Timestamp, Length: 69420, dtype: object>

# %%
pd.to_datetime(
    [1641423598748, 1641423600038, 1641423601901, 1641423603071, 1641423604325],
    unit="ms",
)
# Out:
# DatetimeIndex(['2022-01-05 22:59:58.748000', '2022-01-05 23:00:00.038000',
#                '2022-01-05 23:00:01.901000', '2022-01-05 23:00:03.071000',
#                '2022-01-05 23:00:04.325000'],
#               dtype='datetime64[ns]', freq=None)

# %%
unique_arr = data["Timestamp"].unique()

# %%
unique_arr = data['Timestamp'].to_numpy()

# %%
type(unique_arr)
# Out:
# numpy.ndarray

# %%
converted_arr= [0] * 69420  
type(converted_arr[0])
# Out:
# int

# %%
len(unique_arr)
# Out:
# 69420

# %%
a = unique_arr[0]
a
type(a)
# Out:
# str

# %%
unique_arr_1 = unique_arr[:1000]

# %%
  
for i in unique_arr:
  print (i)
# Out:
#   File "<ipython-input-70-5a999ce63744>", line 3
#     print (i)
#         ^
# IndentationError: expected an indented block

# %%
temp = data_PC1.copy()
temp.columns
# Out:
# Index(['Datum Zeit', 'Timestamp', 'Pres. Comp. (Adam6017A8AIn4)',
#        'Pres. Float 1 (Adam6017A7AIn1)', 'Pres. Float 2 (Adam6017A7AIn2)',
#        'Pres. Float 3 (Adam6017A7AIn3)', 'Pres. Float 4 (Adam6217A5AIn0)',
#        'Pres. Float 5 (Adam6217A5AIn1)', 'Pres. Float 6 (Adam6017A3AIn0)',
#        'Pres. Float 7 (Adam6017A3AIn1)', 'Pres. Float 8 (Adam6017A3AIn2)'],
#       dtype='object')

# %%
type(temp['Timestamp'])
# Out:
# pandas.core.series.Series

# %%
temp.drop(temp.index[temp['Timestamp'] == 'undefined'], inplace = True)

# %%
temp.index = pd.Series(pd.to_datetime(temp['Timestamp'],
    unit="ms"))

temp.index
# Out:
# DatetimeIndex(['2022-01-05 22:59:58.748000', '2022-01-05 23:00:00.038000',
#                '2022-01-05 23:00:01.901000', '2022-01-05 23:00:03.071000',
#                '2022-01-05 23:00:04.325000', '2022-01-05 23:00:05.567000',
#                '2022-01-05 23:00:06.885000', '2022-01-05 23:00:08.156000',
#                '2022-01-05 23:00:09.457000', '2022-01-05 23:00:10.711000',
#                ...
#                '2022-01-06 22:59:46.899000', '2022-01-06 22:59:48.070000',
#                '2022-01-06 22:59:49.230000', '2022-01-06 22:59:50.322000',
#                '2022-01-06 22:59:51.583000', '2022-01-06 22:59:52.862000',
#                '2022-01-06 22:59:54.186000', '2022-01-06 22:59:55.509000',
#                '2022-01-06 22:59:56.595000', '2022-01-06 22:59:57.836000'],
#               dtype='datetime64[ns]', name='Timestamp', length=68785, freq=None)

# %%
temp.head()
# Out:
#                                                       Datum Zeit  ... Pres. Float 8 (Adam6017A3AIn2)
# Timestamp                                                         ...
# 2022-01-05 22:59:58.748  Thu Jan 06 2022 00:00:00 GMT+0100 (CET)  ...                          0.183
# 2022-01-05 23:00:00.038  Thu Jan 06 2022 00:00:01 GMT+0100 (CET)  ...                          0.183
# 2022-01-05 23:00:01.901  Thu Jan 06 2022 00:00:03 GMT+0100 (CET)  ...                          0.183
# 2022-01-05 23:00:03.071  Thu Jan 06 2022 00:00:04 GMT+0100 (CET)  ...                          0.183
# 2022-01-05 23:00:04.325  Thu Jan 06 2022 00:00:05 GMT+0100 (CET)  ...                          0.183
#
# [5 rows x 11 columns]

# %%
temp['Pres. Comp. (Adam6017A8AIn4)'].plot()
temp['Pres. Float 1 (Adam6017A7AIn1)'].plot()
temp['Pres. Float 2 (Adam6017A7AIn2)'].plot()
temp['Pres. Float 3 (Adam6017A7AIn3)'].plot()
temp['Pres. Float 4 (Adam6217A5AIn0)'].plot()
temp['Pres. Float 5 (Adam6217A5AIn1)'].plot()
temp['Pres. Float 6 (Adam6017A3AIn0)'].plot()
temp['Pres. Float 7 (Adam6017A3AIn1)'].plot()
temp['Pres. Float 8 (Adam6017A3AIn2)'].plot()

# %%
j = 0

for i in unique_arr:
  if i == 'undefined':
    break
  a = float(i)
  b = pd.to_datetime(a,
    unit="ms")
  print(b)
  type(b)
  converted_arr.insert(j,b)  
  j += 1
  
converted_arr
# Out:
# Streaming output truncated to the last 5000 lines.
# 2022-01-05 23:03:11.328000
# 2022-01-05 23:03:12.588000
# 2022-01-05 23:03:13.836000
# 2022-01-05 23:03:15.115000
# 2022-01-05 23:03:16.396000
# 2022-01-05 23:03:17.492000
# 2022-01-05 23:03:18.748000
# 2022-01-05 23:03:19.997000
# 2022-01-05 23:03:21.288000
# 2022-01-05 23:03:22.363000
# 2022-01-05 23:03:23.652000
# 2022-01-05 23:03:24.932000
# 2022-01-05 23:03:26.186000
# 2022-01-05 23:03:27.389000
# 2022-01-05 23:03:28.647000
# 2022-01-05 23:03:29.750000
# 2022-01-05 23:03:30.987000
# 2022-01-05 23:03:32.245000
# 2022-01-05 23:03:33.548000
# 2022-01-05 23:03:34.809000
# 2022-01-05 23:03:35.913000
# 2022-01-05 23:03:37.172000
# 2022-01-05 23:03:38.427000
# 2022-01-05 23:03:39.519000
# 2022-01-05 23:03:40.783000
# 2022-01-05 23:03:41.902000
# 2022-01-05 23:03:43.134000
# 2022-01-05 23:03:44.385000
# 2022-01-05 23:03:45.701000
# 2022-01-05 23:03:46.816000
# 2022-01-05 23:03:48.133000
# 2022-01-05 23:03:49.224000
# ...

# %%
type(converted_arr)
# Out:
# list

# %%
converted_arr[:10]
# Out:
# [Timestamp('2022-01-05 22:59:58.748000'),
#  Timestamp('2022-01-05 23:00:00.038000'),
#  Timestamp('2022-01-05 23:00:01.901000'),
#  Timestamp('2022-01-05 23:00:03.071000'),
#  Timestamp('2022-01-05 23:00:04.325000'),
#  Timestamp('2022-01-05 23:00:05.567000'),
#  Timestamp('2022-01-05 23:00:06.885000'),
#  Timestamp('2022-01-05 23:00:08.156000'),
#  Timestamp('2022-01-05 23:00:09.457000'),
#  Timestamp('2022-01-05 23:00:10.711000')]

# %%
# Inilised variable i as 0
i = 0

# Inilised empty string
#string1 = ''

# Run While loop to list length
while i < len(unique_arr):
    # Joint each value of list to final string
    converted_arr[i] = pd.to_datetime(unique_arr[i],
    unit="ms")
    i += 1

# Print final Output
#print(string1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: 'undefined'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-3d7b45d68cc3> in <module>()
#      10     # Joint each value of list to final string
#      11     converted_arr[i] = pd.to_datetime(unique_arr[i],
# ---> 12     unit="ms")
#      13     i += 1
#      14
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     828             result = convert_listlike(arg, format)
#     829     else:
# ...

# %%
 
for i in unique_arr:
  a = i
  pd.to_datetime(
    i,
    unit="ms")
type(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: 'undefined'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-e75987a2a0e6> in <module>()
#       4  pd.to_datetime(
#       5    i,
# ----> 6    unit="ms")
#       7 type(a)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     828             result = convert_listlike(arg, format)
#     829     else:
# --> 830         result = convert_listlike(np.array([arg]), format)[0]
#     831
#     832     return result
#
# ...

# %%
unique_arr.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3770f1546833> in <module>()
# ----> 1 unique_arr.astype(float)
#
# ValueError: could not convert string to float: 'undefined'

# %%
data['Timestamp'] =  pd.to_datetime(data['Timestamp'], unit="ms")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: 'undefined'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-084a20f13792> in <module>()
# ----> 1 data['Timestamp'] =  pd.to_datetime(data['Timestamp'], unit="ms")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     801             result = arg.map(cache_array)
#     802         else:
# --> 803             values = convert_listlike(arg._values, format)
#     804             result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
c = unique_arr[0]
cut_str = c[:10]

print(cut_str)
# Out:
# 1641423598

# %%
unique_arr_0 = unique_arr[0]

# %%
type(unique_arr[0])
# Out:
# str

# %%
from django.utils.text import Truncator
value = Truncator(unique_arr[10]).chars(10)
value
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-108-8fd59dc06332> in <module>()
# ----> 1 from django.utils.text import Truncator
#       2 value = Truncator(unique_arr[10]).chars(10)
#       3 value
#
# ModuleNotFoundError: No module named 'django'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
result = truncate_string(unique_arr[0], 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-980031594c22> in <module>()
#       1
# ----> 2 result = truncate_string(unique_arr[0], 10)
#       3
#       4
#
# NameError: name 'truncate_string' is not defined

# %%
for i in i<10:
  unique_arr[i][:min(len(unique_arr[i]),10)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-15840a2ff38d> in <module>()
#       1 for i in unique_arr:
# ----> 2   unique_arr[i][:min(len(unique_arr[i]),10)]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
np.fromstring(unique_arr, dtype=int, sep=',')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   """Entry point for launching an IPython kernel.
# array([0])

# %%
import numpy as np

a = np.array(unique_arr)

a = a.astype(np.float)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-9f3557399b70> in <module>()
#       3 a = np.array(unique_arr)
#       4
# ----> 5 a = a.astype(np.float)
#       6 a
#
# ValueError: could not convert string to float: 'undefined'

# %%
list = unique_arr
list2 = []
for i in range(len(list)):
  for j in 
   t = float(list[i])
list2.append(t)

print (list2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-e8319b4ef39e> in <module>()
#       2 list2 = []
#       3 for i in range(len(list)):
# ----> 4    t = float(list[i])
#       5 list2.append(t)
#       6
#
# ValueError: could not convert string to float: 'undefined'

# %%
import datetime

timestamp = "1640213998038"
your_dt = datetime.datetime.fromtimestamp(int(timestamp)/1000)  # using the local timezone
print(your_dt.strftime("%Y-%m-%d %H:%M:%S"))
